# %% [markdown]
# <a href="https://colab.research.google.com/github/Drishti-2028/ML-CODES-IMPLEMENTATION/blob/main/ML_ALGOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# Step 1: True labels & Predictions
# -------------------------------
y_true = np.array([0, 0, 1, 1, 0, 1, 0, 1])
y_pred = np.array([0, 1, 1, 1, 0, 0, 0, 1])

# -------------------------------
# Step 2: Confusion Matrix Logic
# -------------------------------
TP = np.sum((y_true == 1) & (y_pred == 1))
TN = np.sum((y_true == 0) & (y_pred == 0))
FP = np.sum((y_true == 0) & (y_pred == 1))
FN = np.sum((y_true == 1) & (y_pred == 0))

conf_matrix = np.array([[TN, FP],
                        [FN, TP]])

print("Confusion Matrix:")
print(conf_matrix)

# -------------------------------
# Step 3: Plot Confusion Matrix
# -------------------------------
plt.figure()
plt.imshow(conf_matrix)
plt.colorbar()

plt.xticks([0, 1], ["Predicted 0", "Predicted 1"])
plt.yticks([0, 1], ["Actual 0", "Actual 1"])

for i in range(2):
    for j in range(2):
        plt.text(j, i, conf_matrix[i, j],
                 ha="center", va="center")

plt.xlabel("Prediction")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[3 1]
#  [1 3]]

# %%
import numpy as np

# ---------------------------------
# Step 1: True labels & Predictions
# ---------------------------------
y_true = np.array([0, 0, 1, 1, 0, 1, 0, 1])
y_pred = np.array([0, 1, 1, 1, 0, 0, 0, 1])

# ---------------------------------
# Step 2: Confusion Matrix Values
# ---------------------------------
TP = np.sum((y_true == 1) & (y_pred == 1))
TN = np.sum((y_true == 0) & (y_pred == 0))
FP = np.sum((y_true == 0) & (y_pred == 1))
FN = np.sum((y_true == 1) & (y_pred == 0))

print("TP:", TP, "TN:", TN, "FP:", FP, "FN:", FN)

# ---------------------------------
# Step 3: Evaluation Metrics
# ---------------------------------
accuracy = (TP + TN) / (TP + TN + FP + FN)

precision = TP / (TP + FP) if (TP + FP) != 0 else 0
recall = TP / (TP + FN) if (TP + FN) != 0 else 0

f1_score = (2 * precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

specificity = TN / (TN + FP) if (TN + FP) != 0 else 0

error_rate = 1 - accuracy

# ---------------------------------
# Step 4: Print Results
# ---------------------------------
print("\nEvaluation Metrics:")
print("Accuracy     :", round(accuracy, 4))
print("Precision    :", round(precision, 4))
print("Recall       :", round(recall, 4))
print("F1 Score     :", round(f1_score, 4))
print("Specificity  :", round(specificity, 4))
print("Error Rate   :", round(error_rate, 4))
# Out:
# TP: 3 TN: 3 FP: 1 FN: 1
#
# Evaluation Metrics:
# Accuracy     : 0.75
# Precision    : 0.75
# Recall       : 0.75
# F1 Score     : 0.75
# Specificity  : 0.75
# Error Rate   : 0.25
