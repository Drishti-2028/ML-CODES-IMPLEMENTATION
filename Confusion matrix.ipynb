# %% [markdown]
# <a href="https://colab.research.google.com/github/Drishti-2028/ML-CODES-IMPLEMENTATION/blob/main/Confusion%20matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------------------------------------
# CONFUSION MATRIX (Binary Classification)
# Full Algorithm + Code Combined
# -----------------------------------------------------------

def confusion_matrix(y_true, y_pred):

    # Step 1: Initialize counters
    TP = TN = FP = FN = 0

    # Step 2: Traverse through all samples
    for i in range(len(y_true)):

        if y_true[i] == 1 and y_pred[i] == 1:
            TP += 1

        elif y_true[i] == 0 and y_pred[i] == 0:
            TN += 1

        elif y_true[i] == 0 and y_pred[i] == 1:
            FP += 1

        elif y_true[i] == 1 and y_pred[i] == 0:
            FN += 1

    # Step 3: Compute performance metrics
    total = TP + TN + FP + FN

    accuracy = (TP + TN) / total if total != 0 else 0

    precision = TP / (TP + FP) if (TP + FP) != 0 else 0

    recall = TP / (TP + FN) if (TP + FN) != 0 else 0

    f1_score = (2 * precision * recall) / (precision + recall) \
               if (precision + recall) != 0 else 0

    # Step 4: Return results
    return {
        "TP": TP,
        "TN": TN,
        "FP": FP,
        "FN": FN,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1_score
    }


# -----------------------------------------------------------
# Example Usage
# -----------------------------------------------------------

if __name__ == "__main__":

    # Actual labels
    y_true = [1, 0, 1, 1, 0, 0, 1, 0]

    # Predicted labels
    y_pred = [1, 0, 1, 0, 0, 1, 1, 0]

    result = confusion_matrix(y_true, y_pred)

    print("Confusion Matrix Results:")
    for key, value in result.items():
        print(f"{key}: {value}")
